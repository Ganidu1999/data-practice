# %%
import numpy as np
data=[15,16,16,17,19,21,21,21,21,22,22,23,25,26,28,29,29,31,31,31,33,34,34,35,36,37,38,38,38,39,39,40,42,42,42,42,42,44,44,44,46,47,48,48,48,49,49,49,50,50]
print(len(data))
print('Mean : ',np.mean(data))
print('Median : ',np.median(data))
print('First Quartile : ',np.percentile(data,25))
print('Second Quartile (Median) : ',np.percentile(data,50))
print('Third Quartile : ',np.percentile(data,75))
print('66% data : ',np.percentile(data,66))
print('Varience ',np.var(data))
print('Standard diviation ',np.std(data))
print(data[int(len(data)/4)])
# Out:
# 50
# Mean :  34.62
# Median :  36.5
# First Quartile :  25.25
# Second Quartile (Median) :  36.5
# Third Quartile :  43.5
# 66% data :  42.0
# Varience  114.0756
# Standard diviation  10.680617959650087
# 25

# %%
import pandas as pd
import matplotlib.pyplot as plt
pd.options.display.max_columns=100
df=pd.read_csv("restaurants.csv")
print(df)
print(df.describe())
print(type(df))
# Out:
#     SHOP_ID               CATEGORY  \
# 0    100001            Coffee shop
# 1    100002                   Cafe
# 2    100003                   Cafe
# 3    100004            Coffee shop
# 4    100005                   Cafe
# ..      ...                    ...
# 74   100075             Restaurant
# 75   100076  Vegetarian restaurant
# 76   100077       Vegan restaurant
# 77   100078  Vegetarian restaurant
# 78   100079       Add phone number
#
#                                                  NAME  RATING PRICE  \
# 0   Java Lounge - Fort - Sri Lanka's Largest Coffe...     4.1    $$
# 1                   The Commons Coffee House at Hatch     4.1   NaN
# 2                              The t-Lounge by Dilmah     4.4    $$
# 3                                             Goodies     4.3    $$
# 4                          Barista World Trade Center     4.2    $$
# ..                                                ...     ...   ...
# 74               Saravana Bawan Vegetarian Restaurant     3.8     $
# 75                                         Royal Vege     4.0   NaN
# 76                         The VOV (Vegan Restaurant)     4.5    $$
# 77                           Reality Vegetable Hunter     4.3   NaN
# 78                Sri Kumaran's New Veggie Restaurant     NaN   NaN
#
#     REVIEW_COUNT                                            ADDRESS  \
# 0          245.0                       7 Hospital St~ Colombo 00100
# 1           50.0                                            Colombo
# 2          780.0                          Chatham St~ Colombo 00100
# 3           68.0              117 Colombo - Batticaloa Hwy~ Colombo
# 4          282.0  Level 3 World Trade Center~ Bank of Ceylon Maw...
# ..           ...                                                ...
# 74         256.0    Colombo - Galle Main Rd~ Dehiwala-Mount Lavinia
# 75           2.0               74a Galle Rd~ Dehiwala-Mount Lavinia
# 76         169.0  No : 117/B/1 Raththanapitiya~ Colombo - Horana...
# 77           6.0                             Dehiwala-Mount Lavinia
# 78           NaN                Templers Rd~ Dehiwala-Mount Lavinia
#
#                                            OPEN_HOURS  \
# 0   ["Friday~ 7AM to 11:45PM; Saturday~ 7AM to 11:...
# 1   ["Friday~ 8AM to 7PM; Saturday~ 8AM to 3PM; Su...
# 2   ["Friday~ 8AM to 9PM; Saturday~ 8AM to 9PM; Su...
# 3   ["Friday~ 7:30AM to 9PM; Saturday~ 7:30AM to 9...
# 4   ["Friday~ 7AM to 7PM; Saturday~ 7AM to 5PM; Su...
# ..                                                ...
# 74  ["Friday~ 8AM to 10PM; Saturday~ 8AM to 10PM; ...
# 75  ["Friday~ 6AM to 10PM; Saturday~ 6AM to 10PM; ...
# 76  ["Friday~ 11AM to 10PM; Saturday~ 11AM to 10PM...
# 77                                                NaN
# 78                                                NaN
#
#                                            BUSY_HOURS
# 0   ['0% busy at 6 AM.'~ '0% busy at 7 AM.'~ '4% b...
# 1                                                 NaN
# 2   ['0% busy at 6 AM.'~ '0% busy at 7 AM.'~ '14% ...
# 3                                                 NaN
# 4   ['% busy at .'~ '0% busy at 6 AM.'~ '18% busy ...
# ..                                                ...
# 74                                                NaN
# 75                                                NaN
# 76                                                NaN
# 77                                                NaN
# 78                                                NaN
#
# [79 rows x 9 columns]
#              SHOP_ID     RATING  REVIEW_COUNT
# count      79.000000  75.000000     75.000000
# mean   100040.000000   4.186667    469.506667
# std        22.949219   0.501170    938.406446
# min    100001.000000   1.500000      1.000000
# 25%    100020.500000   4.000000      9.500000
# 50%    100040.000000   4.100000     68.000000
# 75%    100059.500000   4.400000    373.000000
# max    100079.000000   5.000000   4634.000000
# <class 'pandas.core.frame.DataFrame'>

# %%
col=df['CATEGORY'].values
print(col)
print("2---------------")
print(type(col))
print("3---------------")
print(col[:])
print("4---------------")
print(col[:,2])
print("5---------------")
# Out:
# ['Coffee shop' 'Cafe' 'Cafe' 'Coffee shop' 'Cafe' 'Pastry shop'
#  'Coffee shop' 'Cafe' 'Cafe' 'Coffee shop' 'Coffee shop' 'Cafe'
#  'Coffee store' 'Cafe' 'Cafe' 'Restaurant' 'Coffee shop' 'Cafe' 'Cafe'
#  'Cafe' 'Fast food restaurant' 'Halal restaurant' 'Hamburger restaurant'
#  'Hamburger restaurant' 'Restaurant' 'Fast food restaurant'
#  'Fast food restaurant' 'Fast food restaurant' 'Fast food restaurant'
#  'Fast food restaurant' 'Restaurant' 'Fast food restaurant' 'Restaurant'
#  'Family restaurant' 'Cafe' 'Add phone number' 'Hamburger restaurant'
#  'Hamburger restaurant' 'Hamburger restaurant' 'Ice cream shop'
#  'Ice cream shop' 'Ice cream shop' 'Ice cream shop' 'Ice cream shop'
#  'Ice cream shop' 'Ice cream shop' 'Ice cream shop' 'Ice cream shop'
#  'Ice cream shop' 'Add hours' 'Ice cream shop' 'Ice cream shop'
#  'Ice cream shop' 'Ice cream shop' 'Ice cream shop' 'Ice cream shop'
#  'Ice cream shop' 'Ice cream shop' 'Candy store' 'Vegan restaurant'
#  'Vegetarian restaurant' 'Vegetarian restaurant' 'Vegetarian restaurant'
#  'Vegetarian restaurant' 'Buffet restaurant' 'Vegetarian restaurant'
#  'Restaurant' 'Vegetarian restaurant' 'Restaurant' 'Vegetarian restaurant'
#  'Vegetarian restaurant' 'Vegetarian restaurant' 'Vegetarian restaurant'
#  'Add hours' 'Restaurant' 'Vegetarian restaurant' 'Vegan restaurant'
#  'Vegetarian restaurant' 'Add phone number']
# 2---------------
# <class 'numpy.ndarray'>
# 3---------------
# ['Coffee shop' 'Cafe' 'Cafe' 'Coffee shop' 'Cafe' 'Pastry shop'
#  'Coffee shop' 'Cafe' 'Cafe' 'Coffee shop' 'Coffee shop' 'Cafe'
#  'Coffee store' 'Cafe' 'Cafe' 'Restaurant' 'Coffee shop' 'Cafe' 'Cafe'
#  'Cafe' 'Fast food restaurant' 'Halal restaurant' 'Hamburger restaurant'
#  'Hamburger restaurant' 'Restaurant' 'Fast food restaurant'
#  'Fast food restaurant' 'Fast food restaurant' 'Fast food restaurant'
#  'Fast food restaurant' 'Restaurant' 'Fast food restaurant' 'Restaurant'
#  'Family restaurant' 'Cafe' 'Add phone number' 'Hamburger restaurant'
#  'Hamburger restaurant' 'Hamburger restaurant' 'Ice cream shop'
#  'Ice cream shop' 'Ice cream shop' 'Ice cream shop' 'Ice cream shop'
#  'Ice cream shop' 'Ice cream shop' 'Ice cream shop' 'Ice cream shop'
#  'Ice cream shop' 'Add hours' 'Ice cream shop' 'Ice cream shop'
#  'Ice cream shop' 'Ice cream shop' 'Ice cream shop' 'Ice cream shop'
#  'Ice cream shop' 'Ice cream shop' 'Candy store' 'Vegan restaurant'
#  'Vegetarian restaurant' 'Vegetarian restaurant' 'Vegetarian restaurant'
#  'Vegetarian restaurant' 'Buffet restaurant' 'Vegetarian restaurant'
#  'Restaurant' 'Vegetarian restaurant' 'Restaurant' 'Vegetarian restaurant'
#  'Vegetarian restaurant' 'Vegetarian restaurant' 'Vegetarian restaurant'
#  'Add hours' 'Restaurant' 'Vegetarian restaurant' 'Vegan restaurant'
#  'Vegetarian restaurant' 'Add phone number']
# 4---------------
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-3-83d8083b8bd0> in <module>
#       6 print(col[:])
#       7 print("4---------------")
# ----> 8 print(col[:,2])
#       9 print("5---------------")
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
minidf=df[['CATEGORY','SHOP_ID','ADDRESS']]
print(minidf.head(20))
print(type(minidf))
print(df.head(20))
print(minidf.values) #prints a 2d numpy array
# Out:
#         CATEGORY  SHOP_ID                                            ADDRESS
# 0    Coffee shop   100001                       7 Hospital St~ Colombo 00100
# 1           Cafe   100002                                            Colombo
# 2           Cafe   100003                          Chatham St~ Colombo 00100
# 3    Coffee shop   100004              117 Colombo - Batticaloa Hwy~ Colombo
# 4           Cafe   100005  Level 3 World Trade Center~ Bank of Ceylon Maw...
# 5    Pastry shop   100006                      87A Chatham St~ Colombo 00100
# 6    Coffee shop   100007                                            Colombo
# 7           Cafe   100008                       54 Chatham St~ Colombo 00100
# 8           Cafe   100009                      57 Hospital St~ Colombo 00100
# 9    Coffee shop   100010                        33 Staple St~ Colombo 00200
# 10   Coffee shop   100011         58 a Pepiliyana Rd~ Dehiwala-Mount Lavinia
# 11          Cafe   100012               174 A2~ Dehiwala-Mount Lavinia 10370
# 12  Coffee store   100013  229/1A Kadawatha Rd~ Dehiwala-Mount Lavinia 10350
# 13          Cafe   100014  No 93 ~ Galle Road ~Dehiwala South ~Dehiwala ~...
# 14          Cafe   100015         167/2 Kadawatha Rd~ Dehiwala-Mount Lavinia
# 15    Restaurant   100016       30 De Saram Rd~ Dehiwala-Mount Lavinia 10370
# 16   Coffee shop   100017                      10350~ 89A Anderson Rd~ 10350
# 17          Cafe   100018                             Dehiwala-Mount Lavinia
# 18          Cafe   100019                             Dehiwala-Mount Lavinia
# 19          Cafe   100020                             Dehiwala-Mount Lavinia
# <class 'pandas.core.frame.DataFrame'>
#     SHOP_ID      CATEGORY                                               NAME  \
# 0    100001   Coffee shop  Java Lounge - Fort - Sri Lanka's Largest Coffe...
# 1    100002          Cafe                  The Commons Coffee House at Hatch
# 2    100003          Cafe                             The t-Lounge by Dilmah
# 3    100004   Coffee shop                                            Goodies
# 4    100005          Cafe                         Barista World Trade Center
# 5    100006   Pastry shop                              City Talk Pastry Shop
# 6    100007   Coffee shop                           The Coffee Bean Tea Leaf
# 7    100008          Cafe                PSD Welfare shop and House of Juice
# 8    100009          Cafe                                Kaffeine by Republk
# 9    100010   Coffee shop                                            Barista
# 10   100011   Coffee shop                                      Colombus cafe
# 11   100012          Cafe                      Baguette French Bakery & Cafe
# 12   100013  Coffee store                          The Garrison Coffee House
# 13   100014          Cafe                                       Balindo Cafe
# 14   100015          Cafe                                Coffee And Tea Cafe
# 15   100016    Restaurant                                 Barnes Garden Caf
# 16   100017   Coffee shop                                         Expocoffee
# 17   100018          Cafe                           Everyday Bakery And Cafe
# 18   100019          Cafe                                         Bread Talk
# 19   100020          Cafe                                           HUF cafe
#
#     RATING PRICE  REVIEW_COUNT  \
# 0      4.1    $$         245.0
# 1      4.1   NaN          50.0
# 2      4.4    $$         780.0
# 3      4.3    $$          68.0
# 4      4.2    $$         282.0
# 5      4.8   NaN           6.0
# 6      3.8   NaN           9.0
# 7      4.7   NaN           3.0
# 8      4.3   NaN          10.0
# 9      4.4    $$          69.0
# 10     4.0   NaN           1.0
# 11     4.5   NaN          55.0
# 12     4.8   NaN          34.0
# 13     3.5   NaN           4.0
# 14     4.0   NaN          47.0
# 15     3.7   NaN           3.0
# 16     4.3   NaN          75.0
# 17     3.9     $          45.0
# 18     4.2   $$$         452.0
# 19     4.8   NaN           5.0
#
#                                               ADDRESS  \
# 0                        7 Hospital St~ Colombo 00100
# 1                                             Colombo
# 2                           Chatham St~ Colombo 00100
# 3               117 Colombo - Batticaloa Hwy~ Colombo
# 4   Level 3 World Trade Center~ Bank of Ceylon Maw...
# 5                       87A Chatham St~ Colombo 00100
# 6                                             Colombo
# 7                        54 Chatham St~ Colombo 00100
# 8                       57 Hospital St~ Colombo 00100
# 9                         33 Staple St~ Colombo 00200
# 10         58 a Pepiliyana Rd~ Dehiwala-Mount Lavinia
# 11               174 A2~ Dehiwala-Mount Lavinia 10370
# 12  229/1A Kadawatha Rd~ Dehiwala-Mount Lavinia 10350
# 13  No 93 ~ Galle Road ~Dehiwala South ~Dehiwala ~...
# 14         167/2 Kadawatha Rd~ Dehiwala-Mount Lavinia
# 15       30 De Saram Rd~ Dehiwala-Mount Lavinia 10370
# 16                      10350~ 89A Anderson Rd~ 10350
# 17                             Dehiwala-Mount Lavinia
# 18                             Dehiwala-Mount Lavinia
# 19                             Dehiwala-Mount Lavinia
#
#                                            OPEN_HOURS  \
# 0   ["Friday~ 7AM to 11:45PM; Saturday~ 7AM to 11:...
# 1   ["Friday~ 8AM to 7PM; Saturday~ 8AM to 3PM; Su...
# 2   ["Friday~ 8AM to 9PM; Saturday~ 8AM to 9PM; Su...
# 3   ["Friday~ 7:30AM to 9PM; Saturday~ 7:30AM to 9...
# 4   ["Friday~ 7AM to 7PM; Saturday~ 7AM to 5PM; Su...
# 5   ["Friday~ 7AM to 7PM; Saturday~ 7AM to 4PM; Su...
# 6   ["Friday~ 10AM to 8PM; Saturday~ 10AM to 8PM; ...
# 7   ["Friday~ 6AM to 7PM; Saturday~ 6AM to 5PM; Su...
# 8   ["Friday~ 11AM to 11PM; Saturday~ 11AM to 11PM...
# 9   ["Friday~ 7AM to 11PM; Saturday~ 7AM to 11PM; ...
# 10                                                NaN
# 11  ["Friday~ 9AM to 6PM; Saturday~ 9AM to 6PM; Su...
# 12  ["Friday~ 10AM to 2AM; Saturday~ 10AM to 2AM; ...
# 13  ["Friday~ 7AM to 9PM; Saturday~ 7AM to 9PM; Su...
# 14  ["Friday~ 8AM to 10:30PM; Saturday~ 8AM to 10:...
# 15  ["Friday~ 7 to 10PM; Saturday~ 7 to 10PM; Sund...
# 16  ["Friday~ 9AM to 6PM; Saturday~ 9AM to 6PM; Su...
# 17  ["Friday~ 6AM to 8PM; Saturday~ 6AM to 8PM; Su...
# 18  ["Friday~ 6:30AM to 8PM; Saturday~ 7AM to 7PM;...
# 19  ["Friday~ 9AM to 5PM; Saturday~ 9AM to 5PM; Su...
#
#                                            BUSY_HOURS
# 0   ['0% busy at 6 AM.'~ '0% busy at 7 AM.'~ '4% b...
# 1                                                 NaN
# 2   ['0% busy at 6 AM.'~ '0% busy at 7 AM.'~ '14% ...
# 3                                                 NaN
# 4   ['% busy at .'~ '0% busy at 6 AM.'~ '18% busy ...
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   ['0% busy at 6 AM.'~ '0% busy at 7 AM.'~ '0% b...
# 9   ['0% busy at 6 AM.'~ '0% busy at 7 AM.'~ '1% b...
# 10                                                NaN
# 11  ['0% busy at 6 AM.'~ '0% busy at 7 AM.'~ '0% b...
# 12  ['0% busy at 6 AM.'~ '0% busy at 7 AM.'~ '0% b...
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17  ['0% busy at 5 AM.'~ '31% busy at 6 AM.'~ '36%...
# 18  ['0% busy at 6 AM.'~ '17% busy at 7 AM.'~ '22%...
# 19                                                NaN
# [['Coffee shop' 100001 '7 Hospital St~ Colombo 00100']
#  ['Cafe' 100002 'Colombo']
#  ['Cafe' 100003 'Chatham St~ Colombo 00100']
#  ['Coffee shop' 100004 '117 Colombo - Batticaloa Hwy~ Colombo']
#  ['Cafe' 100005
#   'Level 3 World Trade Center~ Bank of Ceylon Mawatha~ Colombo 00100']
#  ['Pastry shop' 100006 '87A Chatham St~ Colombo 00100']
#  ['Coffee shop' 100007 'Colombo']
#  ['Cafe' 100008 '54 Chatham St~ Colombo 00100']
#  ['Cafe' 100009 '57 Hospital St~ Colombo 00100']
#  ['Coffee shop' 100010 '33 Staple St~ Colombo 00200']
#  ['Coffee shop' 100011 '58 a Pepiliyana Rd~ Dehiwala-Mount Lavinia']
#  ['Cafe' 100012 '174 A2~ Dehiwala-Mount Lavinia 10370']
#  ['Coffee store' 100013
#   '229/1A Kadawatha Rd~ Dehiwala-Mount Lavinia 10350']
#  ['Cafe' 100014
#   'No 93 ~ Galle Road ~Dehiwala South ~Dehiwala ~Sri Lanka 30500~ Colombo - Galle - Hambantota - Wellawaya Hwy~ Dehiwala-Mount Lavinia 30500']
#  ['Cafe' 100015 '167/2 Kadawatha Rd~ Dehiwala-Mount Lavinia']
#  ['Restaurant' 100016 '30 De Saram Rd~ Dehiwala-Mount Lavinia 10370']
#  ['Coffee shop' 100017 '10350~ 89A Anderson Rd~ 10350']
#  ['Cafe' 100018 'Dehiwala-Mount Lavinia']
#  ['Cafe' 100019 'Dehiwala-Mount Lavinia']
#  ['Cafe' 100020 'Dehiwala-Mount Lavinia']
#  ['Fast food restaurant' 100021
#   'Old Dutch Hospital Complex~ Hospital St~ Colombo 00100']
#  ['Halal restaurant' 100022 '1 Vellons Passage~ Colombo 02']
#  ['Hamburger restaurant' 100023 '34 Ramya Rd~ Colombo 00400']
#  ['Hamburger restaurant' 100024 'Colombo 01000']
#  ['Restaurant' 100025
#   'Old Dutch Hospital Complex Echelon Square~ Hospital St~ Colombo 00100']
#  ['Fast food restaurant' 100026 '283 Galle Rd~ Colombo 00300']
#  ['Fast food restaurant' 100027 '283 Galle Rd~ Colombo 00300']
#  ['Fast food restaurant' 100028 'Colombo 01300']
#  ['Fast food restaurant' 100029 'Colombo 00700']
#  ['Fast food restaurant' 100030 'Dehiwala-Mount Lavinia']
#  ['Restaurant' 100031 '126 Hill St~ Dehiwala-Mount Lavinia 10350']
#  ['Fast food restaurant' 100032
#   '293 Galle Rd~ Dehiwala-Mount Lavinia 10350']
#  ['Restaurant' 100033 '45~ Dehiwala-Mount Lavinia']
#  ['Family restaurant' 100034
#   '290~ Dehiwala Road~ Maharagama~ Sri Lanka~ 290 Lake Rd~ Maharagama 10280']
#  ['Cafe' 100035 '50 B11~ Dehiwala-Mount Lavinia']
#  ['Add phone number' 100036 '25 Watarappala Rd~ Dehiwala-Mount Lavinia']
#  ['Hamburger restaurant' 100037 'Marine Dr~ Colombo 10350']
#  ['Hamburger restaurant' 100038 '34 Ramya Rd~ Colombo 00400']
#  ['Hamburger restaurant' 100039
#   'No 25 Station avenue~ Marine Dr~ Colombo']
#  ['Ice cream shop' 100040 '46 Hospital St~ Colombo 00100']
#  ['Ice cream shop' 100041
#   '1 Colombo - Galle - Hambantota - Wellawaya Hwy~ Colombo 00200']
#  ['Ice cream shop' 100042 '263 Colombo - Galle Main Rd~ Colombo 00300']
#  ['Ice cream shop' 100043 'Colombo']
#  ['Ice cream shop' 100044
#   '#LG-K16~ The Mall at One~ Colombo - Galle Main Rd~ Colombo']
#  ['Ice cream shop' 100045 'Colombo 00200']
#  ['Ice cream shop' 100046 '172 Hulftsdorp St~ Colombo']
#  ['Ice cream shop' 100047
#   '1 Colombo - Galle - Hambantota - Wellawaya Hwy~ Colombo 00200']
#  ['Ice cream shop' 100048 'Colombo']
#  ['Ice cream shop' 100049 'Ward Place~ Odel~ Colombo']
#  ['Add hours' 100050 '245 Templers Rd~ Dehiwala-Mount Lavinia']
#  ['Ice cream shop' 100051 'Sastrananda Perivena Mawatha~ Colombo']
#  ['Ice cream shop' 100052 '67~ Ratmalana Rd~ Dehiwala-Mount Lavinia']
#  ['Ice cream shop' 100053 '581 Galle Rd~ Colombo 00600']
#  ['Ice cream shop' 100054 'Middle Way~ Dehiwala-Mount Lavinia']
#  ['Ice cream shop' 100055 '35/7 Raymond Rd~ Nugegoda']
#  ['Ice cream shop' 100056 '4A Wellawatta Station Rd~ Colombo']
#  ['Ice cream shop' 100057 'Moratuwa 10400']
#  ['Ice cream shop' 100058 '29 Colombo Plan Rd~ Marine Drive~ Colombo']
#  ['Candy store' 100059 'Dehiwala-Mount Lavinia']
#  ['Vegan restaurant' 100060 '131 2nd Cross Street~ Colombo 01100']
#  ['Vegetarian restaurant' 100061 '01100~ 98 Bankshall St~ Colombo 01100']
#  ['Vegetarian restaurant' 100062 '23 5th Cross St~ Colombo']
#  ['Vegetarian restaurant' 100063 'Colombo 01000']
#  ['Vegetarian restaurant' 100064 '255 Sea St~ Colombo 01100']
#  ['Buffet restaurant' 100065
#   '2 Sir Chittampalam A Gardiner Mawatha~ 00200']
#  ['Vegetarian restaurant' 100066 '230 Sea St~ Colombo 01300']
#  ['Restaurant' 100067 'NO 05 Chatham St~ Colombo 00100']
#  ['Vegetarian restaurant' 100068 '38 New Chetty St~ Colombo 01300']
#  ['Restaurant' 100069
#   'Old Dutch Hospital Complex Echelon Square~ Hospital St~ Colombo 00100']
#  ['Vegetarian restaurant' 100070 '74a A2~ Dehiwala-Mount Lavinia']
#  ['Vegetarian restaurant' 100071
#   '306 Hospital Rd~ Dehiwala-Mount Lavinia']
#  ['Vegetarian restaurant' 100072 'saravana-bawan.business.site']
#  ['Vegetarian restaurant' 100073 '53/3 Ramakrishna Rd~ Colombo 00600']
#  ['Add hours' 100074 'No 305 Hill St~ Dehiwala-Mount Lavinia']
#  ['Restaurant' 100075 'Colombo - Galle Main Rd~ Dehiwala-Mount Lavinia']
#  ['Vegetarian restaurant' 100076 '74a Galle Rd~ Dehiwala-Mount Lavinia']
#  ['Vegan restaurant' 100077
#   'No : 117/B/1 Raththanapitiya~ Colombo - Horana Rd~ Boralesgamuwa 10290']
#  ['Vegetarian restaurant' 100078 'Dehiwala-Mount Lavinia']
#  ['Add phone number' 100079 'Templers Rd~ Dehiwala-Mount Lavinia']]

# %%
minidf['CAFE']=minidf['CATEGORY']=='Cafe' #adding a extra column CAFE where if it return tue if CATEGORY is cafe
print(minidf)
# Out:
#                  CATEGORY  SHOP_ID  \
# 0             Coffee shop   100001
# 1                    Cafe   100002
# 2                    Cafe   100003
# 3             Coffee shop   100004
# 4                    Cafe   100005
# ..                    ...      ...
# 74             Restaurant   100075
# 75  Vegetarian restaurant   100076
# 76       Vegan restaurant   100077
# 77  Vegetarian restaurant   100078
# 78       Add phone number   100079
#
#                                               ADDRESS   CAFE
# 0                        7 Hospital St~ Colombo 00100  False
# 1                                             Colombo   True
# 2                           Chatham St~ Colombo 00100   True
# 3               117 Colombo - Batticaloa Hwy~ Colombo  False
# 4   Level 3 World Trade Center~ Bank of Ceylon Maw...   True
# ..                                                ...    ...
# 74    Colombo - Galle Main Rd~ Dehiwala-Mount Lavinia  False
# 75               74a Galle Rd~ Dehiwala-Mount Lavinia  False
# 76  No : 117/B/1 Raththanapitiya~ Colombo - Horana...  False
# 77                             Dehiwala-Mount Lavinia  False
# 78                Templers Rd~ Dehiwala-Mount Lavinia  False
#
# [79 rows x 4 columns]
# <ipython-input-5-2e256fe16450>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   minidf['CAFE']=minidf['CATEGORY']=='Cafe' #adding a extra column CAFE where if it return tue if CATEGORY is cafe

# %%
array=df['SHOP_ID'].head(10).values
print(df['SHOP_ID'].head(10).values,type(array))#values attribute returns a 1d array

# %%
lk=df[['CATEGORY','PRICE']].values  #=[[Row1],[Row2],[Row3]] CATEGORY,PRICE acts as references to their memory locations like indexes
print(lk.shape)
print(lk[2][1])
print(lk[:,1])#selects index 1 element ofeveryinner array":" stands for normal array operation array[start:end]
print(lk[0:3,1])
print(lk[:10]) #simple array operation

# %%
df['HIGH_RATED']=df['RATING']>=4.0
addressesAndIds=df[['SHOP_ID','ADDRESS','RATING','HIGH_RATED']].values
print(addressesAndIds)
addresses=addressesAndIds[:,1]
print(addresses)
# Out:
# [[100001 '7 Hospital St~ Colombo 00100' 4.1 True]
#  [100002 'Colombo' 4.1 True]
#  [100003 'Chatham St~ Colombo 00100' 4.4 True]
#  [100004 '117 Colombo - Batticaloa Hwy~ Colombo' 4.3 True]
#  [100005
#   'Level 3 World Trade Center~ Bank of Ceylon Mawatha~ Colombo 00100' 4.2
#   True]
#  [100006 '87A Chatham St~ Colombo 00100' 4.8 True]
#  [100007 'Colombo' 3.8 False]
#  [100008 '54 Chatham St~ Colombo 00100' 4.7 True]
#  [100009 '57 Hospital St~ Colombo 00100' 4.3 True]
#  [100010 '33 Staple St~ Colombo 00200' 4.4 True]
#  [100011 '58 a Pepiliyana Rd~ Dehiwala-Mount Lavinia' 4.0 True]
#  [100012 '174 A2~ Dehiwala-Mount Lavinia 10370' 4.5 True]
#  [100013 '229/1A Kadawatha Rd~ Dehiwala-Mount Lavinia 10350' 4.8 True]
#  [100014
#   'No 93 ~ Galle Road ~Dehiwala South ~Dehiwala ~Sri Lanka 30500~ Colombo - Galle - Hambantota - Wellawaya Hwy~ Dehiwala-Mount Lavinia 30500'
#   3.5 False]
#  [100015 '167/2 Kadawatha Rd~ Dehiwala-Mount Lavinia' 4.0 True]
#  [100016 '30 De Saram Rd~ Dehiwala-Mount Lavinia 10370' 3.7 False]
#  [100017 '10350~ 89A Anderson Rd~ 10350' 4.3 True]
#  [100018 'Dehiwala-Mount Lavinia' 3.9 False]
#  [100019 'Dehiwala-Mount Lavinia' 4.2 True]
#  [100020 'Dehiwala-Mount Lavinia' 4.8 True]
#  [100021 'Old Dutch Hospital Complex~ Hospital St~ Colombo 00100' 4.1
#   True]
#  [100022 '1 Vellons Passage~ Colombo 02' 4.1 True]
#  [100023 '34 Ramya Rd~ Colombo 00400' 4.4 True]
#  [100024 'Colombo 01000' 4.5 True]
#  [100025
#   'Old Dutch Hospital Complex Echelon Square~ Hospital St~ Colombo 00100'
#   3.9 False]
#  [100026 '283 Galle Rd~ Colombo 00300' 4.1 True]
#  [100027 '283 Galle Rd~ Colombo 00300' 4.1 True]
#  [100028 'Colombo 01300' 3.9 False]
#  [100029 'Colombo 00700' 4.1 True]
#  [100030 'Dehiwala-Mount Lavinia' 4.1 True]
#  [100031 '126 Hill St~ Dehiwala-Mount Lavinia 10350' 4.2 True]
#  [100032 '293 Galle Rd~ Dehiwala-Mount Lavinia 10350' 3.9 False]
#  [100033 '45~ Dehiwala-Mount Lavinia' 3.9 False]
#  [100034
#   '290~ Dehiwala Road~ Maharagama~ Sri Lanka~ 290 Lake Rd~ Maharagama 10280'
#   3.7 False]
#  [100035 '50 B11~ Dehiwala-Mount Lavinia' 4.1 True]
#  [100036 '25 Watarappala Rd~ Dehiwala-Mount Lavinia' nan False]
#  [100037 'Marine Dr~ Colombo 10350' 4.7 True]
#  [100038 '34 Ramya Rd~ Colombo 00400' 4.4 True]
#  [100039 'No 25 Station avenue~ Marine Dr~ Colombo' 4.6 True]
#  [100040 '46 Hospital St~ Colombo 00100' 5.0 True]
#  [100041 '1 Colombo - Galle - Hambantota - Wellawaya Hwy~ Colombo 00200'
#   4.0 True]
#  [100042 '263 Colombo - Galle Main Rd~ Colombo 00300' 4.3 True]
#  [100043 'Colombo' 5.0 True]
#  [100044 '#LG-K16~ The Mall at One~ Colombo - Galle Main Rd~ Colombo' 4.5
#   True]
#  [100045 'Colombo 00200' 5.0 True]
#  [100046 '172 Hulftsdorp St~ Colombo' 4.8 True]
#  [100047 '1 Colombo - Galle - Hambantota - Wellawaya Hwy~ Colombo 00200'
#   5.0 True]
#  [100048 'Colombo' 4.4 True]
#  [100049 'Ward Place~ Odel~ Colombo' 4.0 True]
#  [100050 '245 Templers Rd~ Dehiwala-Mount Lavinia' nan False]
#  [100051 'Sastrananda Perivena Mawatha~ Colombo' 4.1 True]
#  [100052 '67~ Ratmalana Rd~ Dehiwala-Mount Lavinia' 4.1 True]
#  [100053 '581 Galle Rd~ Colombo 00600' 4.5 True]
#  [100054 'Middle Way~ Dehiwala-Mount Lavinia' 4.0 True]
#  [100055 '35/7 Raymond Rd~ Nugegoda' 1.5 False]
#  [100056 '4A Wellawatta Station Rd~ Colombo' 4.1 True]
#  [100057 'Moratuwa 10400' 4.4 True]
#  [100058 '29 Colombo Plan Rd~ Marine Drive~ Colombo' 4.4 True]
#  [100059 'Dehiwala-Mount Lavinia' 4.4 True]
#  [100060 '131 2nd Cross Street~ Colombo 01100' 4.4 True]
#  [100061 '01100~ 98 Bankshall St~ Colombo 01100' 4.1 True]
#  [100062 '23 5th Cross St~ Colombo' 4.0 True]
#  [100063 'Colombo 01000' 4.1 True]
#  [100064 '255 Sea St~ Colombo 01100' 4.2 True]
#  [100065 '2 Sir Chittampalam A Gardiner Mawatha~ 00200' 4.6 True]
#  [100066 '230 Sea St~ Colombo 01300' 4.1 True]
#  [100067 'NO 05 Chatham St~ Colombo 00100' 4.1 True]
#  [100068 '38 New Chetty St~ Colombo 01300' 4.1 True]
#  [100069
#   'Old Dutch Hospital Complex Echelon Square~ Hospital St~ Colombo 00100'
#   3.9 False]
#  [100070 '74a A2~ Dehiwala-Mount Lavinia' 3.9 False]
#  [100071 '306 Hospital Rd~ Dehiwala-Mount Lavinia' 4.2 True]
#  [100072 'saravana-bawan.business.site' 2.4 False]
#  [100073 '53/3 Ramakrishna Rd~ Colombo 00600' 4.2 True]
#  [100074 'No 305 Hill St~ Dehiwala-Mount Lavinia' nan False]
#  [100075 'Colombo - Galle Main Rd~ Dehiwala-Mount Lavinia' 3.8 False]
#  [100076 '74a Galle Rd~ Dehiwala-Mount Lavinia' 4.0 True]
#  [100077
#   'No : 117/B/1 Raththanapitiya~ Colombo - Horana Rd~ Boralesgamuwa 10290'
#   4.5 True]
#  [100078 'Dehiwala-Mount Lavinia' 4.3 True]
#  [100079 'Templers Rd~ Dehiwala-Mount Lavinia' nan False]]
# ['7 Hospital St~ Colombo 00100' 'Colombo' 'Chatham St~ Colombo 00100'
#  '117 Colombo - Batticaloa Hwy~ Colombo'
#  'Level 3 World Trade Center~ Bank of Ceylon Mawatha~ Colombo 00100'
#  '87A Chatham St~ Colombo 00100' 'Colombo' '54 Chatham St~ Colombo 00100'
#  '57 Hospital St~ Colombo 00100' '33 Staple St~ Colombo 00200'
#  '58 a Pepiliyana Rd~ Dehiwala-Mount Lavinia'
#  '174 A2~ Dehiwala-Mount Lavinia 10370'
#  '229/1A Kadawatha Rd~ Dehiwala-Mount Lavinia 10350'
#  'No 93 ~ Galle Road ~Dehiwala South ~Dehiwala ~Sri Lanka 30500~ Colombo - Galle - Hambantota - Wellawaya Hwy~ Dehiwala-Mount Lavinia 30500'
#  '167/2 Kadawatha Rd~ Dehiwala-Mount Lavinia'
#  '30 De Saram Rd~ Dehiwala-Mount Lavinia 10370'
#  '10350~ 89A Anderson Rd~ 10350' 'Dehiwala-Mount Lavinia'
#  'Dehiwala-Mount Lavinia' 'Dehiwala-Mount Lavinia'
#  'Old Dutch Hospital Complex~ Hospital St~ Colombo 00100'
#  '1 Vellons Passage~ Colombo 02' '34 Ramya Rd~ Colombo 00400'
#  'Colombo 01000'
#  'Old Dutch Hospital Complex Echelon Square~ Hospital St~ Colombo 00100'
#  '283 Galle Rd~ Colombo 00300' '283 Galle Rd~ Colombo 00300'
#  'Colombo 01300' 'Colombo 00700' 'Dehiwala-Mount Lavinia'
#  '126 Hill St~ Dehiwala-Mount Lavinia 10350'
#  '293 Galle Rd~ Dehiwala-Mount Lavinia 10350' '45~ Dehiwala-Mount Lavinia'
#  '290~ Dehiwala Road~ Maharagama~ Sri Lanka~ 290 Lake Rd~ Maharagama 10280'
#  '50 B11~ Dehiwala-Mount Lavinia'
#  '25 Watarappala Rd~ Dehiwala-Mount Lavinia' 'Marine Dr~ Colombo 10350'
#  '34 Ramya Rd~ Colombo 00400' 'No 25 Station avenue~ Marine Dr~ Colombo'
#  '46 Hospital St~ Colombo 00100'
#  '1 Colombo - Galle - Hambantota - Wellawaya Hwy~ Colombo 00200'
#  '263 Colombo - Galle Main Rd~ Colombo 00300' 'Colombo'
#  '#LG-K16~ The Mall at One~ Colombo - Galle Main Rd~ Colombo'
#  'Colombo 00200' '172 Hulftsdorp St~ Colombo'
#  '1 Colombo - Galle - Hambantota - Wellawaya Hwy~ Colombo 00200' 'Colombo'
#  'Ward Place~ Odel~ Colombo' '245 Templers Rd~ Dehiwala-Mount Lavinia'
#  'Sastrananda Perivena Mawatha~ Colombo'
#  '67~ Ratmalana Rd~ Dehiwala-Mount Lavinia' '581 Galle Rd~ Colombo 00600'
#  'Middle Way~ Dehiwala-Mount Lavinia' '35/7 Raymond Rd~ Nugegoda'
#  '4A Wellawatta Station Rd~ Colombo' 'Moratuwa 10400'
#  '29 Colombo Plan Rd~ Marine Drive~ Colombo' 'Dehiwala-Mount Lavinia'
#  '131 2nd Cross Street~ Colombo 01100'
#  '01100~ 98 Bankshall St~ Colombo 01100' '23 5th Cross St~ Colombo'
#  'Colombo 01000' '255 Sea St~ Colombo 01100'
#  '2 Sir Chittampalam A Gardiner Mawatha~ 00200'
#  '230 Sea St~ Colombo 01300' 'NO 05 Chatham St~ Colombo 00100'
#  '38 New Chetty St~ Colombo 01300'
#  'Old Dutch Hospital Complex Echelon Square~ Hospital St~ Colombo 00100'
#  '74a A2~ Dehiwala-Mount Lavinia'
#  '306 Hospital Rd~ Dehiwala-Mount Lavinia' 'saravana-bawan.business.site'
#  '53/3 Ramakrishna Rd~ Colombo 00600'
#  'No 305 Hill St~ Dehiwala-Mount Lavinia'
#  'Colombo - Galle Main Rd~ Dehiwala-Mount Lavinia'
#  '74a Galle Rd~ Dehiwala-Mount Lavinia'
#  'No : 117/B/1 Raththanapitiya~ Colombo - Horana Rd~ Boralesgamuwa 10290'
#  'Dehiwala-Mount Lavinia' 'Templers Rd~ Dehiwala-Mount Lavinia']

# %%
mask=addressesAndIds[:,2]>4.0
print(mask)
print(type(mask))
print(addressesAndIds[:,2]>4.0)
print(addressesAndIds[mask])
print(addressesAndIds[addressesAndIds[:,2]>4.0])
print((addressesAndIds[:,2]>4.0).sum()) #summing up all the true values(1)

# %%
graph=plt.scatter(df['REVIEW_COUNT'],df['RATING'])

# %%
plt.xlabel('REVIEW_COUNT')
plt.ylabel('RATING')
plt.scatter(df['REVIEW_COUNT'],df['RATING'],c=df['HIGH_RATED'])
plt.plot([0,4000],[4.25,4.25],color='red') #this is a list of x values and y values [[x1,x2],[y1,y2]]
plt.show()
